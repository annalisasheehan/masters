# %%
import numpy as np
import xarray as xr
import rasterio
# %matplotlib inline
from matplotlib.pyplot import *
from glob import glob
import os
import datetime

import pandas as pd

from rasterio import features

from rasterio_to_xarray import rasterio_to_xarray, xarray_to_rasterio

import rasterstats
import fiona

from tqdm import tqdm

from shapely.geometry import shape
from rasterstats.io import read_features

#from dask.diagnostics import ProgressBar

# %% [markdown]
# pbar = ProgressBar()
# pbar.register()

# %% [markdown]
# pbar.unregister()

# %%
data = xr.open_dataset('http://opendap.knmi.nl/knmi/thredds/dodsC/e-obs_0.25regular/tg_stderr_0.25deg_reg_v13.1.nc')

# %%
tg = data['tg']

# %% [markdown]
# ## Monthly data for South of UK

# %%
# %time monthly = tg.sel(time=slice('2009-01-01','2016-07-01')).resample('M', dim='time', how='mean')
# Out:
# Wall time: 1min 18s

# %%
uk = tg.sel(longitude=slice(-10,3), latitude=slice(50,54))

# %%
# %time uk_monthly = uk.sel(time=slice('2009-01-01','2016-07-01')).resample('M', dim='time', how='mean')
# Out:
# Wall time: 7.75 s

# %%
data = uk_monthly

# %% [markdown]
# The next few cells are the bits that convert the affine transform

# %%
# Image to rasterize the polygons in to
rasterized_image = np.zeros(data.isel(time=0).shape, dtype=np.int)

# List to store dataframes in
dfs = []

feats = read_features(r'D:\Annies_Dissertation\Data\Boundaries\LSOA_WGS.shp')

out_shape = data.isel(time=0).shape

# %% [markdown]
# This single line is the key thing that makes the code faster!

# %%
data = data.load()

# %%
data
# Out:
# <xarray.DataArray 'tg' (time: 84, latitude: 16, longitude: 52)>
# array([[[        nan,         nan,         nan, ...,  1.40935481,
#           1.42354836,  1.43129029],
#         [        nan,         nan,         nan, ...,  1.466129  ,
#           1.44580642,  1.41064513],
#         [        nan,         nan,         nan, ...,  1.35774191,
#           1.35903223,  1.39677416],
#         ...,
#         [        nan,  1.47838706,  1.33387094, ...,         nan,
#                  nan,         nan],
#         [ 1.45516126,  1.40709674,  1.31580642, ...,         nan,
#                  nan,         nan],
#         [        nan,  1.42516126,  1.36225803, ...,         nan,
#                  nan,         nan]],
#
#        [[        nan,         nan,         nan, ...,  1.31035711,
#           1.2960714 ,  1.28749997],
#         [        nan,         nan,         nan, ...,  1.31214283,
#           1.30035711,  1.30499997],
#         [        nan,         nan,         nan, ...,  1.27821426,
#           1.27785711,  1.30321426],
#         ...,
#         [        nan,  1.40642854,  1.30928569, ...,         nan,
#                  nan,         nan],
#         [ 1.39821425,  1.37178568,  1.2935714 , ...,         nan,
#                  nan,         nan],
#         [        nan,  1.3760714 ,  1.32928568, ...,         nan,
#                  nan,         nan]],
#
#        [[        nan,         nan,         nan, ...,  1.06161288,
#           1.05258062,  1.04999998],
#         [        nan,         nan,         nan, ...,  1.06580643,
#           1.05677417,  1.05709675],
#         [        nan,         nan,         nan, ...,  1.03483869,
#           1.0329032 ,  1.05580643],
#         ...,
#         [        nan,  1.20838707,  1.11032256, ...,         nan,
#                  nan,         nan],
#         [ 1.19612901,  1.17064514,  1.09322578, ...,         nan,
#                  nan,         nan],
#         [        nan,  1.16709675,  1.12258062, ...,         nan,
#                  nan,         nan]],
#
#        ...,
#        [[ 0.85999998,  0.85096772,  0.84451611, ...,  0.71774192,
#           0.73096773,  0.72193547],
#         [ 0.86645159,  0.87903224,  0.85225805, ...,  0.75741934,
#           0.74516127,  0.74161289],
#         [ 0.87870966,  0.82032256,  0.82387095, ...,  0.78935482,
#           0.78258063,  0.78451611],
#         ...,
#         [        nan,         nan,         nan, ...,  0.74903224,
#           0.74870966,  0.73612902],
#         [        nan,         nan,         nan, ...,  0.73258063,
#           0.74451611,  0.74225805],
#         [        nan,         nan,         nan, ...,         nan,
#           0.7464516 ,  0.74161289]],
#
#        [[ 1.08399998,  1.06766664,  1.06233331, ...,  1.01633331,
#           1.01799998,  1.00766664],
#         [ 1.08199998,  1.08866664,  1.07199998, ...,  1.06833331,
#           1.03999998,  1.01399998],
#         [ 1.08466664,  1.04133331,  1.05233331, ...,  1.09199998,
#           1.06466664,  1.04099998],
#         ...,
#         [        nan,         nan,         nan, ...,  1.02333331,
#           1.01133331,  0.98099998],
#         [        nan,         nan,         nan, ...,  0.96199998,
#           0.98099998,  0.98233331],
#         [        nan,         nan,         nan, ...,         nan,
#           0.98099998,  0.97766664]],
#
#        [[ 1.12741933,  1.09677417,  1.08612901, ...,  1.09387094,
#           1.09999998,  1.08741933],
#         [ 1.11612901,  1.1029032 ,  1.09064514, ...,  1.11258062,
#           1.09709675,  1.08774191],
#         [ 1.10225804,  1.07322578,  1.07193546, ...,  1.11354836,
#           1.10806449,  1.08612901],
#         ...,
#         [        nan,         nan,         nan, ...,  1.12193546,
#           1.10161288,  1.07193546],
#         [        nan,         nan,         nan, ...,  1.04806449,
#           1.0629032 ,  1.06774191],
#         [        nan,         nan,         nan, ...,         nan,
#           1.0712903 ,  1.06548385]]])
# Coordinates:
#   * longitude  (longitude) float32 -9.875 -9.625 -9.375 -9.125 -8.875 -8.625 ...
#   * latitude   (latitude) float32 50.125 50.375 50.625 50.875 51.125 51.375 ...
#   * time       (time) datetime64[ns] 2009-01-31 2009-02-28 2009-03-31 ...

# %%
# Loop over features (polygons) in the shapefile
for f in tqdm(feats):
    # Rasterize the polygon into an array
    rasterized_image = features.rasterize([(shape(f['geometry']),1)],
                                          out_shape=out_shape,
                                          fill=0,
                                          all_touched=True)

    # Extract from the xarray where the rasterized polygon is
    region = data.where(rasterized_image == 1)
    
    # Combine x and y into a new dimension called allpoints and calculate the mean over it
    # and then convert to a dataframe with an appropriate name
    res = region.stack(allpoints=['longitude','latitude']).mean(dim='allpoints').to_dataframe(name=f['properties']['LSOA11CD'])
    
    # Append to the list of data frames so we can concatenate them all at the end
    dfs.append(res)
    
stats = pd.concat(dfs, axis=1)
# Out:
# 2576it [00:18, 138.49it/s]

# %%
stats
# Out:
#             E01014891  E01015272  E01015273  E01015274  E01015275  E01015276  \
# time
# 2009-01-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-02-28        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-03-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-04-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-05-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-06-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-07-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-08-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-09-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-10-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-11-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-12-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-01-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-02-28        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-03-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-04-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-05-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-06-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-07-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-08-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-09-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-10-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-11-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-12-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2011-01-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2011-02-28        NaN        NaN        NaN        NaN        NaN        NaN
# 2011-03-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2011-04-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2011-05-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2011-06-30        NaN        NaN        NaN        NaN        NaN        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2013-07-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2013-08-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2013-09-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2013-10-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2013-11-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2013-12-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-01-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-02-28        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-03-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-04-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-05-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-06-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-07-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-08-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-09-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-10-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-11-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-12-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-01-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-02-28        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-03-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-04-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-05-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-06-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-07-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-08-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-09-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-10-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-11-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-12-31        NaN        NaN        NaN        NaN        NaN        NaN
#
#             E01015277  E01015279  E01015280  E01015281    ...      E01033241  \
# time                                                      ...
# 2009-01-31        NaN        NaN        NaN        NaN    ...            NaN
# 2009-02-28        NaN        NaN        NaN        NaN    ...            NaN
# 2009-03-31        NaN        NaN        NaN        NaN    ...            NaN
# 2009-04-30        NaN        NaN        NaN        NaN    ...            NaN
# 2009-05-31        NaN        NaN        NaN        NaN    ...            NaN
# 2009-06-30        NaN        NaN        NaN        NaN    ...            NaN
# 2009-07-31        NaN        NaN        NaN        NaN    ...            NaN
# 2009-08-31        NaN        NaN        NaN        NaN    ...            NaN
# 2009-09-30        NaN        NaN        NaN        NaN    ...            NaN
# 2009-10-31        NaN        NaN        NaN        NaN    ...            NaN
# 2009-11-30        NaN        NaN        NaN        NaN    ...            NaN
# 2009-12-31        NaN        NaN        NaN        NaN    ...            NaN
# 2010-01-31        NaN        NaN        NaN        NaN    ...            NaN
# 2010-02-28        NaN        NaN        NaN        NaN    ...            NaN
# 2010-03-31        NaN        NaN        NaN        NaN    ...            NaN
# 2010-04-30        NaN        NaN        NaN        NaN    ...            NaN
# 2010-05-31        NaN        NaN        NaN        NaN    ...            NaN
# 2010-06-30        NaN        NaN        NaN        NaN    ...            NaN
# 2010-07-31        NaN        NaN        NaN        NaN    ...            NaN
# 2010-08-31        NaN        NaN        NaN        NaN    ...            NaN
# 2010-09-30        NaN        NaN        NaN        NaN    ...            NaN
# 2010-10-31        NaN        NaN        NaN        NaN    ...            NaN
# 2010-11-30        NaN        NaN        NaN        NaN    ...            NaN
# 2010-12-31        NaN        NaN        NaN        NaN    ...            NaN
# 2011-01-31        NaN        NaN        NaN        NaN    ...            NaN
# 2011-02-28        NaN        NaN        NaN        NaN    ...            NaN
# 2011-03-31        NaN        NaN        NaN        NaN    ...            NaN
# 2011-04-30        NaN        NaN        NaN        NaN    ...            NaN
# 2011-05-31        NaN        NaN        NaN        NaN    ...            NaN
# 2011-06-30        NaN        NaN        NaN        NaN    ...            NaN
# ...               ...        ...        ...        ...    ...            ...
# 2013-07-31        NaN        NaN        NaN        NaN    ...            NaN
# 2013-08-31        NaN        NaN        NaN        NaN    ...            NaN
# 2013-09-30        NaN        NaN        NaN        NaN    ...            NaN
# 2013-10-31        NaN        NaN        NaN        NaN    ...            NaN
# 2013-11-30        NaN        NaN        NaN        NaN    ...            NaN
# 2013-12-31        NaN        NaN        NaN        NaN    ...            NaN
# 2014-01-31        NaN        NaN        NaN        NaN    ...            NaN
# 2014-02-28        NaN        NaN        NaN        NaN    ...            NaN
# 2014-03-31        NaN        NaN        NaN        NaN    ...            NaN
# 2014-04-30        NaN        NaN        NaN        NaN    ...            NaN
# 2014-05-31        NaN        NaN        NaN        NaN    ...            NaN
# 2014-06-30        NaN        NaN        NaN        NaN    ...            NaN
# 2014-07-31        NaN        NaN        NaN        NaN    ...            NaN
# 2014-08-31        NaN        NaN        NaN        NaN    ...            NaN
# 2014-09-30        NaN        NaN        NaN        NaN    ...            NaN
# 2014-10-31        NaN        NaN        NaN        NaN    ...            NaN
# 2014-11-30        NaN        NaN        NaN        NaN    ...            NaN
# 2014-12-31        NaN        NaN        NaN        NaN    ...            NaN
# 2015-01-31        NaN        NaN        NaN        NaN    ...            NaN
# 2015-02-28        NaN        NaN        NaN        NaN    ...            NaN
# 2015-03-31        NaN        NaN        NaN        NaN    ...            NaN
# 2015-04-30        NaN        NaN        NaN        NaN    ...            NaN
# 2015-05-31        NaN        NaN        NaN        NaN    ...            NaN
# 2015-06-30        NaN        NaN        NaN        NaN    ...            NaN
# 2015-07-31        NaN        NaN        NaN        NaN    ...            NaN
# 2015-08-31        NaN        NaN        NaN        NaN    ...            NaN
# 2015-09-30        NaN        NaN        NaN        NaN    ...            NaN
# 2015-10-31        NaN        NaN        NaN        NaN    ...            NaN
# 2015-11-30        NaN        NaN        NaN        NaN    ...            NaN
# 2015-12-31        NaN        NaN        NaN        NaN    ...            NaN
#
#             E01033242  E01033283  E01033285  E01033286  E01033288  E01033380  \
# time
# 2009-01-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-02-28        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-03-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-04-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-05-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-06-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-07-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-08-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-09-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-10-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-11-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2009-12-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-01-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-02-28        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-03-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-04-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-05-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-06-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-07-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-08-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-09-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-10-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-11-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2010-12-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2011-01-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2011-02-28        NaN        NaN        NaN        NaN        NaN        NaN
# 2011-03-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2011-04-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2011-05-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2011-06-30        NaN        NaN        NaN        NaN        NaN        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2013-07-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2013-08-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2013-09-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2013-10-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2013-11-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2013-12-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-01-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-02-28        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-03-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-04-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-05-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-06-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-07-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-08-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-09-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-10-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-11-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-12-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-01-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-02-28        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-03-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-04-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-05-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-06-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-07-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-08-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-09-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-10-31        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-11-30        NaN        NaN        NaN        NaN        NaN        NaN
# 2015-12-31        NaN        NaN        NaN        NaN        NaN        NaN
#
#             E01033381  E01033383  E01033384
# time
# 2009-01-31        NaN        NaN        NaN
# 2009-02-28        NaN        NaN        NaN
# 2009-03-31        NaN        NaN        NaN
# 2009-04-30        NaN        NaN        NaN
# 2009-05-31        NaN        NaN        NaN
# 2009-06-30        NaN        NaN        NaN
# 2009-07-31        NaN        NaN        NaN
# 2009-08-31        NaN        NaN        NaN
# 2009-09-30        NaN        NaN        NaN
# 2009-10-31        NaN        NaN        NaN
# 2009-11-30        NaN        NaN        NaN
# 2009-12-31        NaN        NaN        NaN
# 2010-01-31        NaN        NaN        NaN
# 2010-02-28        NaN        NaN        NaN
# 2010-03-31        NaN        NaN        NaN
# 2010-04-30        NaN        NaN        NaN
# 2010-05-31        NaN        NaN        NaN
# 2010-06-30        NaN        NaN        NaN
# 2010-07-31        NaN        NaN        NaN
# 2010-08-31        NaN        NaN        NaN
# 2010-09-30        NaN        NaN        NaN
# 2010-10-31        NaN        NaN        NaN
# 2010-11-30        NaN        NaN        NaN
# 2010-12-31        NaN        NaN        NaN
# 2011-01-31        NaN        NaN        NaN
# 2011-02-28        NaN        NaN        NaN
# 2011-03-31        NaN        NaN        NaN
# 2011-04-30        NaN        NaN        NaN
# 2011-05-31        NaN        NaN        NaN
# 2011-06-30        NaN        NaN        NaN
# ...               ...        ...        ...
# 2013-07-31        NaN        NaN        NaN
# 2013-08-31        NaN        NaN        NaN
# 2013-09-30        NaN        NaN        NaN
# 2013-10-31        NaN        NaN        NaN
# 2013-11-30        NaN        NaN        NaN
# 2013-12-31        NaN        NaN        NaN
# 2014-01-31        NaN        NaN        NaN
# 2014-02-28        NaN        NaN        NaN
# 2014-03-31        NaN        NaN        NaN
# 2014-04-30        NaN        NaN        NaN
# 2014-05-31        NaN        NaN        NaN
# 2014-06-30        NaN        NaN        NaN
# 2014-07-31        NaN        NaN        NaN
# 2014-08-31        NaN        NaN        NaN
# 2014-09-30        NaN        NaN        NaN
# 2014-10-31        NaN        NaN        NaN
# 2014-11-30        NaN        NaN        NaN
# 2014-12-31        NaN        NaN        NaN
# 2015-01-31        NaN        NaN        NaN
# 2015-02-28        NaN        NaN        NaN
# 2015-03-31        NaN        NaN        NaN
# 2015-04-30        NaN        NaN        NaN
# 2015-05-31        NaN        NaN        NaN
# 2015-06-30        NaN        NaN        NaN
# 2015-07-31        NaN        NaN        NaN
# 2015-08-31        NaN        NaN        NaN
# 2015-09-30        NaN        NaN        NaN
# 2015-10-31        NaN        NaN        NaN
# 2015-11-30        NaN        NaN        NaN
# 2015-12-31        NaN        NaN        NaN
#
# [84 rows x 2576 columns]

# %%
stats = stats.dropna(how='all')

# %%
melted_stats = pd.melt(stats.reset_index(), id_vars='time', var_name='LSOA').dropna()

# %%
melted_stats
# Out:
# Empty DataFrame
# Columns: [time, LSOA, value]
# Index: []

# %%
melted_stats['month'] = melted_stats.time.dt.month

# %%
melted_stats['year'] = melted_stats.time.dt.year

# %%
melted_stats.head()

# %%
melted_stats.to_csv(r'D:\Annies_Dissertation\Analysis\Regression\MSOA\Monthly_Temp_LSOA.csv')

# %% [markdown]
# ## Validating with AP for a LSOA (E01017182) that is located within a pixel

# %%
PM25 = xr.open_mfdataset(r'C:\MAIACData\nc_monthly_daily\*PM25.nc')['data']

# %%
PM25

# %%
a = PM25.attrs['affine']
a = rasterio.Affine.from_gdal(*a)
~a * (439040, 115775)

# %%
PM25 = PM25.isel(time=np.argsort(PM25.time))

# %%
After2009 = PM25.sel(time=slice('2009', '2016'))

# %%
monthly_data = After2009.resample('M', dim='time', how='mean', keep_attrs=True)

# %%
ts = monthly_data.isel(x=1103, y=1045).load()

# %%
ts

# %%
result = ts.to_dataframe()

# %%
result.dropna()

# %%
result.to_csv(r'D:\Annies_Dissertation\Analysis\Regression\Validation\Monthly_PM25_LSOA_Validation.csv')

# %% [markdown]
# ### Joining data for pixel and LSOA to validate Rasterstats method

# %%
from dateutil.parser import parse

# %%
Pixel = pd.read_csv(r'D:\Annies_Dissertation\Analysis\Regression\Validation\Monthly_PM25_LSOA_Validation.csv', parse_dates=['time'])

# %%
Pixel[:10]

# %%
Pixel = Pixel.set_index('time')

# %%
Pixel = Pixel[['data']].dropna()

# %%
Pixel['LSOA'] = 'E01017182'

# %%
Area = pd.read_csv(r'D:\Annies_Dissertation\Analysis\Regression\Monthly_PM25_LSOA.csv', parse_dates=['time'])

# %%
Area[:10]

# %%
Area = Area.set_index('time')

# %%
Area = Area[['LSOA', 'value']].dropna()

# %%
E01 = Area.loc[Area['LSOA'] == 'E01017182']

# %%
E01

# %%
result = pd.merge(Pixel, E01, left_index=True, right_index=True)

# %%
result.dropna()

# %%
result['Difference'] = result['data']- result['value']

# %%
result[:10]

# %%
result.Difference.value_counts()

# %%
result.groupby('Difference').count()

# %% [markdown]
# ## Yearly

# %%
yearly_data = After2009.resample('A', dim='time', how='mean', keep_attrs=True)

# %%
yearly_data

# %%
data = yearly_data

# %%
# Get the actual Affine object from the data stored in the attrs
orig_aff = rasterio.Affine.from_gdal(*data.attrs['affine'])

# %%
def window_bounds(window, affine):
    (row_start, row_stop), (col_start, col_stop) = window
    w, s = (col_start, row_stop) * affine
    e, n = (col_stop, row_start) * affine
    return w, s, e, n

# %%
c, _, _, f = window_bounds( ( (x_start, 5000), (y_start, 5000)), orig_aff)  # c ~ west, f ~ north
a, b, _, d, e, _, _, _, _ = tuple(orig_aff)
new_aff = rasterio.Affine(a, b, c, d, e, f)

# %%
orig_aff

# %%
new_aff

# %%
# Image to rasterize the polygons in to
rasterized_image = np.zeros(data.isel(time=0).shape, dtype=np.int)

# List to store dataframes in
dfs = []

feats = read_features(r'D:\Annies_Dissertation\Data\Boundaries\LSOA_Wessex.shp')

out_shape = data.isel(time=0).shape

# %%
data = data.load()

# %%
# Loop over features (polygons) in the shapefile
for f in tqdm(feats):
    # Rasterize the polygon into an array
    rasterized_image = features.rasterize([(shape(f['geometry']),1)],
                                          out_shape=out_shape,
                                          transform=new_aff,
                                          fill=0,
                                          all_touched=True)

    # Extract from the xarray where the rasterized polygon is
    region = data.where(rasterized_image == 1)
    
    # Combine x and y into a new dimension called allpoints and calculate the mean over it
    # and then convert to a dataframe with an appropriate name
    res = region.stack(allpoints=['x','y']).mean(dim='allpoints').to_dataframe(name=f['properties']['LSOA11CD'])
    
    # Append to the list of data frames so we can concatenate them all at the end
    dfs.append(res)
    
stats = pd.concat(dfs, axis=1)

# %%
stats

# %%
stats = stats.dropna(how='all')

# %%
melted_stats = pd.melt(stats.reset_index(), id_vars='time', var_name='LSOA').dropna()

# %%
melted_stats

# %%
melted_stats['year'] = melted_stats.time.dt.year

# %%
melted_stats.head()

# %%
melted_stats.to_csv(r'D:\Annies_Dissertation\Analysis\Regression\Yearly_PM25_LSOA.csv')
